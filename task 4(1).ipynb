# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import pandas as pd
import time

# %%
driver_path = "C:/webdrivers/chromedriver.exe"  # or your full path like "C:/path/to/chromedriver.exe"
service = Service(driver_path)

# Start Chrome browser
driver = webdriver.Chrome(service=service)

# Open the Uniqlo T-shirts page
url = "https://www.uniqlo.com/us/en/men/tops/t-shirts?path=%2C%2C23386%2C&sort=0"
driver.get(url)

# Give the page some time to load dynamic content
time.sleep(5)

# Find product containers
products = driver.find_elements(By.CSS_SELECTOR, 'div.fr-ec-product-tile__end.fr-ec-product-tile__end--padding')

# Prepare data lists
product_names = []
product_prices = []
product_ratings = []
product_rating_counts = []

# Extract product data
for product in products:
    try:
        name = product.find_element(By.CSS_SELECTOR, 'h3.fr-ec-title').text
    except:
        name = 'N/A'
    
    try:
        price = product.find_element(By.CSS_SELECTOR, 'div.fr-ec-price').text
    except:
        price = 'N/A'
    
    try:
        rating = product.find_element(By.CSS_SELECTOR, 'div.fr-ec-rating-average-product-tile').text
    except:
        rating = 'N/A'

    try:
        rating_count = product.find_element(By.CSS_SELECTOR, 'div.fr-ec-rating-static__count-product-tile').text
    except:
        rating_count = 'N/A'
    
    product_names.append(name)
    product_prices.append(price)
    product_ratings.append(rating)
    product_rating_counts.append(rating_count)

# Close the browser
driver.quit()

# Create DataFrame
df = pd.DataFrame({
    'Product Name': product_names,
    'Price': product_prices,
    'Rating': product_ratings,
    'Rating Count': product_rating_counts
})

# Show table
print(df)
# Out:
#                                        Product Name   Price Rating  \
# 0     AIRism Cotton Oversized T-Shirt | Half-Sleeve  $14.90    4.8
# 1   AIRism Cotton T-Shirt | Striped | Contrast Trim  $14.90    4.8
# 2                             AIRism Cotton T-Shirt  $14.90    4.4
# 3                    AIRism Cotton T-Shirt | V-Neck  $19.90    3.6
# 4                            SUPIMA® Cotton T-Shirt  $24.90    4.6
# 5                                 Crew Neck T-Shirt  $19.90    4.5
# 6                  Crew Neck Sweater | Short Sleeve  $39.90    4.5
# 7                                    DRY-EX T-Shirt  $24.90    4.7
# 8                          DRY-EX T-Shirt | Printed  $24.90      5
# 9                                    DRY-EX T-Shirt  $14.90    4.6
# 10                        DRY Waffle Henley T-Shirt  $24.90    4.9
# 11                                DRY Color T-Shirt   $7.90    4.7
# 12                                DRY Color T-Shirt   $7.90    4.4
# 13                   Crew Neck T-Shirt | 3/4 Sleeve  $14.90    4.5
# 14    AIRism Cotton Oversized T-Shirt | Half-Sleeve  $14.90    N/A
# 15                         DRY-EX T-Shirt | Mapping  $24.90    N/A
#
#    Rating Count
# 0        (999+)
# 1          (33)
# 2          (34)
# 3           (3)
# 4         (754)
# 5        (999+)
# 6          (14)
# 7          (89)
# 8          (11)
# 9          (34)
# 10         (13)
# 11        (228)
# 12        (361)
# 13         (12)
# 14          N/A
# 15          N/A

# %%
# !pip install undetected_chromedriver
import undetected_chromedriver as uc

driver = uc.Chrome()

url = "https://www.levi.com/US/en_US/clothing/men/shirts/c/levi_clothing_men_shirts/sort/bestseller"
driver.get(url)

# Give the page some time to load dynamic content
time.sleep(5)

# Find product containers
products = driver.find_elements(By.CSS_SELECTOR, 'div.product-details')

# Prepare data lists
product_names = []
product_prices = []
product_ratings = []
product_rating_counts = []

# Extract product data
for product in products:
    try:
        name = product.find_element(By.CSS_SELECTOR, 'h3.product-name').text
    except:
        name = 'N/A'
    
    try:
        price = product.find_element(By.CSS_SELECTOR, 'div.product-price').text
    except:
        price = 'N/A'
    
    try:
        rating_style = product.find_element(By.CSS_SELECTOR, 'div.overall-rating-stars.filled').get_attribute("style")
        width_percentage = float(rating_style.split(":")[1].replace("%;", "").strip())
        rating = round(width_percentage / 20, 1)  # 100% → 5 stars
    except:
        rating = 'N/A'
        
    try:
        rating_count = product.find_element(By.CSS_SELECTOR, 'span.overall-rating-text').text
    except:
        rating_count = 'N/A'
        
    
    product_names.append(name)
    product_prices.append(price)
    product_ratings.append(rating)
    product_rating_counts.append(rating_count)

# Close the browser
driver.quit()

# Create DataFrame
df = pd.DataFrame({
    'Product Name': product_names,
    'Price': product_prices,
    'Rating': product_ratings,
    'Rating Count': product_rating_counts
})

# Show table
print(df)
# Out:
# Collecting undetected_chromedriver
#   Downloading undetected-chromedriver-3.5.5.tar.gz (65 kB)
# Requirement already satisfied: selenium>=4.9.0 in c:\users\murtuja afshar\anaconda3\lib\site-packages (from undetected_chromedriver) (4.25.0)
# Requirement already satisfied: requests in c:\users\murtuja afshar\anaconda3\lib\site-packages (from undetected_chromedriver) (2.27.1)
# Collecting websockets
#   Downloading websockets-15.0.1-cp39-cp39-win_amd64.whl (176 kB)
# Requirement already satisfied: trio~=0.17 in c:\users\murtuja afshar\anaconda3\lib\site-packages (from selenium>=4.9.0->undetected_chromedriver) (0.27.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\murtuja afshar\anaconda3\lib\site-packages (from selenium>=4.9.0->undetected_chromedriver) (2021.10.8)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\murtuja afshar\anaconda3\lib\site-packages (from selenium>=4.9.0->undetected_chromedriver) (1.8.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\murtuja afshar\anaconda3\lib\site-packages (from selenium>=4.9.0->undetected_chromedriver) (0.11.1)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\murtuja afshar\anaconda3\lib\site-packages (from selenium>=4.9.0->undetected_chromedriver) (1.26.9)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\murtuja afshar\anaconda3\lib\site-packages (from selenium>=4.9.0->undetected_chromedriver) (4.12.2)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\murtuja afshar\anaconda3\lib\site-packages (from trio~=0.17->selenium>=4.9.0->undetected_chromedriver) (24.2.0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\murtuja afshar\anaconda3\lib\site-packages (from trio~=0.17->selenium>=4.9.0->undetected_chromedriver) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\murtuja afshar\anaconda3\lib\site-packages (from trio~=0.17->selenium>=4.9.0->undetected_chromedriver) (1.15.0)
# Requirement already satisfied: outcome in c:\users\murtuja afshar\anaconda3\lib\site-packages (from trio~=0.17->selenium>=4.9.0->undetected_chromedriver) (1.3.0.post0)
# Requirement already satisfied: sortedcontainers in c:\users\murtuja afshar\anaconda3\lib\site-packages (from trio~=0.17->selenium>=4.9.0->undetected_chromedriver) (2.4.0)
# Requirement already satisfied: idna in c:\users\murtuja afshar\anaconda3\lib\site-packages (from trio~=0.17->selenium>=4.9.0->undetected_chromedriver) (3.3)
# Requirement already satisfied: exceptiongroup in c:\users\murtuja afshar\anaconda3\lib\site-packages (from trio~=0.17->selenium>=4.9.0->undetected_chromedriver) (1.2.2)
# Requirement already satisfied: pycparser in c:\users\murtuja afshar\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium>=4.9.0->undetected_chromedriver) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\murtuja afshar\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium>=4.9.0->undetected_chromedriver) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\murtuja afshar\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium>=4.9.0->undetected_chromedriver) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\murtuja afshar\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium>=4.9.0->undetected_chromedriver) (0.14.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\murtuja afshar\anaconda3\lib\site-packages (from requests->undetected_chromedriver) (2.0.4)
# Building wheels for collected packages: undetected-chromedriver
#   Building wheel for undetected-chromedriver (setup.py): started
#   Building wheel for undetected-chromedriver (setup.py): finished with status 'done'
#   Created wheel for undetected-chromedriver: filename=undetected_chromedriver-3.5.5-py3-none-any.whl size=47065 sha256=3ce72240d4bf587ad8bbd0f2fde10b9989c7e3b3e7e1e91058bfa2bb7eeabd8d
#   Stored in directory: c:\users\murtuja afshar\appdata\local\pip\cache\wheels\d1\9c\b4\ccdca75ca356899a9b65190f048a03058f1fe23602c642b88e
# Successfully built undetected-chromedriver
# Installing collected packages: websockets, undetected-chromedriver
# Successfully installed undetected-chromedriver-3.5.5 websockets-15.0.1
#                                Product Name  \
# 0              Levi's® Logo Classic T-Shirt
# 1   Levi's® Sportswear Logo Graphic T-Shirt
# 2        Classic Western Standard Fit Shirt
# 3               Barstow Western Denim Shirt
# 4                      Housemark Polo Shirt
# ..                                      ...
# 67
# 68
# 69
# 70
# 71
#
#                                                 Price  Rating Rating Count
# 0                                              $24.50     4.3        (422)
# 1   Temporary Price Range is\n$14.99 - $24.50\nOri...     4.2        (127)
# 2   Temporary Price is\n$48.65\nOriginal Price was...     4.4        (466)
# 3   Sale Price Range is\n$53.98 - $79.50\nOriginal...     4.3        (369)
# 4   Temporary Price is\n$19.99\nOriginal Price was...     4.6        (173)
# ..                                                ...     ...          ...
# 67                                                        5.0
# 68                                                        4.0
# 69                                                        4.4
# 70                                                        4.0
# 71                                                        4.6
#
# [72 rows x 4 columns]

# %%
df.to_csv('levi_products.csv', index=False)

# %%
print(df)
# Out:
#                                Product Name  \
# 0              Levi's® Logo Classic T-Shirt
# 1   Levi's® Sportswear Logo Graphic T-Shirt
# 2        Classic Western Standard Fit Shirt
# 3               Barstow Western Denim Shirt
# 4                      Housemark Polo Shirt
# ..                                      ...
# 67
# 68
# 69
# 70
# 71
#
#                                                 Price  Rating Rating Count
# 0                                              $24.50     4.3        (422)
# 1   Temporary Price Range is\n$14.99 - $24.50\nOri...     4.2        (127)
# 2   Temporary Price is\n$48.65\nOriginal Price was...     4.4        (466)
# 3   Sale Price Range is\n$53.98 - $79.50\nOriginal...     4.3        (369)
# 4   Temporary Price is\n$19.99\nOriginal Price was...     4.6        (173)
# ..                                                ...     ...          ...
# 67                                                        5.0
# 68                                                        4.0
# 69                                                        4.4
# 70                                                        4.0
# 71                                                        4.6
#
# [72 rows x 4 columns]

# %%
# Clean up newlines
df['Price'] = df['Price'].str.replace('\n', ' | ')

# Clean up rating counts
df['Rating Count'] = df['Rating Count'].str.replace('(', '').str.replace(')', '')

# Save to CSV
df.to_csv('levi_products_clean.csv', index=False)
# Out:
# C:\Users\Murtuja afshar\AppData\Local\Temp\ipykernel_5920\3062194671.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Rating Count'] = df['Rating Count'].str.replace('(', '').str.replace(')', '')
